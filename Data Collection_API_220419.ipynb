# %%
import requests

# %%
req.json()
# Out:
# {'items': [{'id': '54735504',
#    'premium': False,
#    'name': 'Copywriter/Content Manager',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-04-17T16:15:02+0300',
#    'created_at': '2022-04-17T16:15:02+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=54735504',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/54735504?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/54735504',
#    'relations': [],
#    'employer': {'id': '3199199',
#     'name': 'eCarsTrade',
#     'url': 'https://api.hh.ru/employers/3199199',
#     'alternate_url': 'https://hh.ru/employer/3199199',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2664674.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/2664673.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/555800.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3199199',
#     'trusted': True},
#    'snippet': {'requirement': 'Hard skills. English level: C2. Your texts must be easy-to-read for non-native readers and also loved...',
#     'responsibility': 'From idea to design. Product texts. Write short clear texts, <highlighttext>name</highlighttext> new features, buttons, etc. SMM. Create a content plan...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '54771811',
#    'premium': False,
#    'name': 'Senior Product Designer',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-04-12T18:47:40+0300',
#    'created_at': '2022-04-12T18:47:40+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=54771811',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/54771811?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/54771811',
#    'relations': [],
#    'employer': {'id': '3230136',
#     'name': 'Smartcat',
#     'url': 'https://api.hh.ru/employers/3230136',
#     'alternate_url': 'https://hh.ru/employer/3230136',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/2562701.png',
#      '240': 'https://hhcdn.ru/employer-logo/2562702.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/530306.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3230136',
#     'trusted': True},
#    'snippet': {'requirement': 'Experience designing experiences that people can access on any type of device: desktop, tablet, phone. Ability to design polished, high...',
#     'responsibility': 'And since Smartcat’s main audience is other people who make <highlighttext>translations</highlighttext>, we agonize over and take pride in crafting...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '54737819',
#    'premium': False,
#    'name': 'Customer Experience Specialist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Отрадная улица',
#     'building': '2Бс6',
#     'description': None,
#     'lat': 55.856558,
#     'lng': 37.599498,
#     'raw': 'Москва, Отрадная улица, 2Бс6',
#     'metro': {'station_name': 'Отрадное',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.97',
#      'line_id': '9',
#      'lat': 55.864273,
#      'lng': 37.605066},
#     'metro_stations': [{'station_name': 'Отрадное',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.97',
#       'line_id': '9',
#       'lat': 55.864273,
#       'lng': 37.605066}],
#     'id': '1863772'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-04-11T17:13:33+0300',
#    'created_at': '2022-04-11T17:13:33+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=54737819',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/54737819?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/54737819',
#    'relations': [],
#    'employer': {'id': '3230136',
#     'name': 'Smartcat',
#     'url': 'https://api.hh.ru/employers/3230136',
#     'alternate_url': 'https://hh.ru/employer/3230136',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/2562701.png',
#      '240': 'https://hhcdn.ru/employer-logo/2562702.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/530306.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3230136',
#     'trusted': True},
#    'snippet': {'requirement': 'Excellent written communication skills in English and Russian. Truly love helping and teaching people. Possess exceptional troubleshooting and problem-solving...',
#     'responsibility': 'Resolve customer support inquiries and requests in modern ticketing systems such as Zendesk and YouTrack. Brainstorm and troubleshoot complex issues. '},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '54737809',
#    'premium': False,
#    'name': 'Customer Experience Specialist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '2',
#     'name': 'Санкт-Петербург',
#     'url': 'https://api.hh.ru/areas/2'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Отрадная улица',
#     'building': '2Бс6',
#     'description': None,
#     'lat': 55.856558,
#     'lng': 37.599498,
#     'raw': 'Москва, Отрадная улица, 2Бс6',
#     'metro': {'station_name': 'Отрадное',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.97',
#      'line_id': '9',
#      'lat': 55.864273,
#      'lng': 37.605066},
#     'metro_stations': [{'station_name': 'Отрадное',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.97',
#       'line_id': '9',
#       'lat': 55.864273,
#       'lng': 37.605066}],
#     'id': '1863772'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-04-11T17:13:15+0300',
#    'created_at': '2022-04-11T17:13:15+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=54737809',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/54737809?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/54737809',
#    'relations': [],
#    'employer': {'id': '3230136',
#     'name': 'Smartcat',
#     'url': 'https://api.hh.ru/employers/3230136',
#     'alternate_url': 'https://hh.ru/employer/3230136',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/2562701.png',
#      '240': 'https://hhcdn.ru/employer-logo/2562702.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/530306.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3230136',
#     'trusted': True},
#    'snippet': {'requirement': 'Excellent written communication skills in English and Russian. Truly love helping and teaching people. Possess exceptional troubleshooting and problem-solving...',
#     'responsibility': 'Resolve customer support inquiries and requests in modern ticketing systems such as Zendesk and YouTrack. Brainstorm and troubleshoot complex issues. '},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '54686484',
#    'premium': False,
#    'name': 'Юрист по комплаенсу и судебной работе',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-04-08T14:53:35+0300',
#    'created_at': '2022-04-08T14:53:35+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=54686484',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/54686484?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/54686484',
#    'relations': [],
#    'employer': {'id': '2765',
#     'name': 'Manpower',
#     'url': 'https://api.hh.ru/employers/2765',
#     'alternate_url': 'https://hh.ru/employer/2765',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/4228277.png',
#      '90': 'https://hhcdn.ru/employer-logo/4228276.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/946935.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2765',
#     'trusted': True},
#    'snippet': {'requirement': 'Degree in law of reputable university (MSU/MGIMO/Legal Academy <highlighttext>named</highlighttext> by Kutafin/ S-Petersburg University/Samara University/ Voronezh University). ',
#     'responsibility': 'Reviewing/preparing/updating contracts (mostly Retail agreements, Distribution agreements and marketing agreements). Customer services: legal support of different routine matters. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '52304887',
#    'premium': False,
#    'name': 'Product Owner at Smartcat',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-04-05T17:53:41+0300',
#    'created_at': '2022-04-05T17:53:41+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=52304887',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/52304887?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/52304887',
#    'relations': [],
#    'employer': {'id': '3230136',
#     'name': 'Smartcat',
#     'url': 'https://api.hh.ru/employers/3230136',
#     'alternate_url': 'https://hh.ru/employer/3230136',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/2562701.png',
#      '240': 'https://hhcdn.ru/employer-logo/2562702.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/530306.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3230136',
#     'trusted': True},
#    'snippet': {'requirement': '5 years of product management experience in a fast-paced tech company or startup (B2B SaaS and/or...',
#     'responsibility': 'Define and execute the product roadmap that is central in helping Smartcat understand and manage the <highlighttext>translation</highlighttext> industry for end...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '52530338',
#    'premium': False,
#    'name': 'Product Owner at Smartcat',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '2',
#     'name': 'Санкт-Петербург',
#     'url': 'https://api.hh.ru/areas/2'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Отрадная улица',
#     'building': '2Бс6',
#     'description': None,
#     'lat': 55.856558,
#     'lng': 37.599498,
#     'raw': 'Москва, Отрадная улица, 2Бс6',
#     'metro': {'station_name': 'Отрадное',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.97',
#      'line_id': '9',
#      'lat': 55.864273,
#      'lng': 37.605066},
#     'metro_stations': [{'station_name': 'Отрадное',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.97',
#       'line_id': '9',
#       'lat': 55.864273,
#       'lng': 37.605066}],
#     'id': '1863772'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-04-05T17:53:41+0300',
#    'created_at': '2022-04-05T17:53:41+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=52530338',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/52530338?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/52530338',
#    'relations': [],
#    'employer': {'id': '3230136',
#     'name': 'Smartcat',
#     'url': 'https://api.hh.ru/employers/3230136',
#     'alternate_url': 'https://hh.ru/employer/3230136',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/2562701.png',
#      '240': 'https://hhcdn.ru/employer-logo/2562702.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/530306.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3230136',
#     'trusted': True},
#    'snippet': {'requirement': '5 years of product management experience in a fast-paced tech company or startup (B2B SaaS and/or...',
#     'responsibility': 'Define and execute the product roadmap that is central in helping Smartcat understand and manage the <highlighttext>translation</highlighttext> industry for end...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '53232070',
#    'premium': False,
#    'name': 'Talent Acquisition Manager (Global)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-04-05T17:53:41+0300',
#    'created_at': '2022-04-05T17:53:41+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=53232070',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/53232070?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/53232070',
#    'relations': [],
#    'employer': {'id': '3230136',
#     'name': 'Smartcat',
#     'url': 'https://api.hh.ru/employers/3230136',
#     'alternate_url': 'https://hh.ru/employer/3230136',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/2562701.png',
#      '240': 'https://hhcdn.ru/employer-logo/2562702.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/530306.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3230136',
#     'trusted': True},
#    'snippet': {'requirement': '2 years of experience in recruiting globally. Fluent English. Growth-oriented mindset. Readiness to work in a highly intense startup...',
#     'responsibility': 'CV sourcing and screening the candidates from the USA, UK, Europe with the goal to find A-players. Onboard employees. '},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '53232071',
#    'premium': False,
#    'name': 'Talent Acquisition Manager (Global)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '2',
#     'name': 'Санкт-Петербург',
#     'url': 'https://api.hh.ru/areas/2'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-04-05T17:53:41+0300',
#    'created_at': '2022-04-05T17:53:41+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=53232071',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/53232071?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/53232071',
#    'relations': [],
#    'employer': {'id': '3230136',
#     'name': 'Smartcat',
#     'url': 'https://api.hh.ru/employers/3230136',
#     'alternate_url': 'https://hh.ru/employer/3230136',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/2562701.png',
#      '240': 'https://hhcdn.ru/employer-logo/2562702.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/530306.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3230136',
#     'trusted': True},
#    'snippet': {'requirement': '2 years of experience in recruiting globally. Fluent English. Growth-oriented mindset. Readiness to work in a highly intense startup...',
#     'responsibility': 'CV sourcing and screening the candidates from the USA, UK, Europe with the goal to find A-players. Onboard employees. '},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False}],
#  'found': 9,
#  'pages': 1,
#  'per_page': 20,
#  'page': 0,
#  'clusters': None,
#  'arguments': None,
#  'alternate_url': 'https://hh.ru/search/vacancy?area=1&area=2&enable_snippets=true&text=NAME+translator'}

# %%
url = 'https://api.hh.ru/vacancies'
params = {
    'text': 'NAME: translator',
    'area': {2, 1}
}
req = requests.get(url, params)
if req.status_code == 200:
    print(req.content)
else:
    print('Error')
# Out:
# b'{"items":[{"id":"54735504","premium":false,"name":"Copywriter/Content Manager","department":null,"has_test":false,"response_letter_required":false,"area":{"id":"1","name":"\xd0\x9c\xd0\xbe\xd1\x81\xd0\xba\xd0\xb2\xd0\xb0","url":"https://api.hh.ru/areas/1"},"salary":null,"type":{"id":"open","name":"\xd0\x9e\xd1\x82\xd0\xba\xd1\x80\xd1\x8b\xd1\x82\xd0\xb0\xd1\x8f"},"address":null,"response_url":null,"sort_point_distance":null,"published_at":"2022-04-17T16:15:02+0300","created_at":"2022-04-17T16:15:02+0300","archived":false,"apply_alternate_url":"https://hh.ru/applicant/vacancy_response?vacancyId=54735504","insider_interview":null,"url":"https://api.hh.ru/vacancies/54735504?host=hh.ru","alternate_url":"https://hh.ru/vacancy/54735504","relations":[],"employer":{"id":"3199199","name":"eCarsTrade","url":"https://api.hh.ru/employers/3199199","alternate_url":"https://hh.ru/employer/3199199","logo_urls":{"240":"https://hhcdn.ru/employer-logo/2664674.jpeg","90":"https://hhcdn.ru/employer-logo/2664673.jpeg","original":"https://hhcdn.ru/employer-logo-original/555800.jpg"},"vacancies_url":"https://api.hh.ru/vacancies?employer_id=3199199","trusted":true},"snippet":{"requirement":"Hard skills. English level: C2. Your texts must be easy-to-read for non-native readers and also loved...","responsibility":"From idea to design. Product texts. Write short clear texts, <highlighttext>name</highlighttext> new features, buttons, etc. SMM. Create a content plan..."},"contacts":null,"schedule":{"id":"fullDay","name":"\xd0\x9f\xd0\xbe\xd0\xbb\xd0\xbd\xd1\x8b\xd0\xb9 \xd0\xb4\xd0\xb5\xd0\xbd\xd1\x8c"},"working_days":[],"working_time_intervals":[],"working_time_modes":[],"accept_temporary":false},{"id":"54771811","premium":false,"name":"Senior Product Designer","department":null,"has_test":false,"response_letter_required":false,"area":{"id":"1","name":"\xd0\x9c\xd0\xbe\xd1\x81\xd0\xba\xd0\xb2\xd0\xb0","url":"https://api.hh.ru/areas/1"},"salary":null,"type":{"id":"open","name":"\xd0\x9e\xd1\x82\xd0\xba\xd1\x80\xd1\x8b\xd1\x82\xd0\xb0\xd1\x8f"},"address":null,"response_url":null,"sort_point_distance":null,"published_at":"2022-04-12T18:47:40+0300","created_at":"2022-04-12T18:47:40+0300","archived":false,"apply_alternate_url":"https://hh.ru/applicant/vacancy_response?vacancyId=54771811","insider_interview":null,"url":"https://api.hh.ru/vacancies/54771811?host=hh.ru","alternate_url":"https://hh.ru/vacancy/54771811","relations":[],"employer":{"id":"3230136","name":"Smartcat","url":"https://api.hh.ru/employers/3230136","alternate_url":"https://hh.ru/employer/3230136","logo_urls":{"90":"https://hhcdn.ru/employer-logo/2562701.png","240":"https://hhcdn.ru/employer-logo/2562702.png","original":"https://hhcdn.ru/employer-logo-original/530306.png"},"vacancies_url":"https://api.hh.ru/vacancies?employer_id=3230136","trusted":true},"snippet":{"requirement":"Experience designing experiences that people can access on any type of device: desktop, tablet, phone. Ability to design polished, high...","responsibility":"And since Smartcat\xe2\x80\x99s main audience is other people who make <highlighttext>translations</highlighttext>, we agonize over and take pride in crafting..."},"contacts":null,"schedule":{"id":"remote","name":"\xd0\xa3\xd0\xb4\xd0\xb0\xd0\xbb\xd0\xb5\xd0\xbd\xd0\xbd\xd0\xb0\xd1\x8f \xd1\x80\xd0\xb0\xd0\xb1\xd0\xbe\xd1\x82\xd0\xb0"},"working_days":[],"working_time_intervals":[],"working_time_modes":[],"accept_temporary":false},{"id":"54737819","premium":false,"name":"Customer Experience Specialist","department":null,"has_test":false,"response_letter_required":false,"area":{"id":"1","name":"\xd0\x9c\xd0\xbe\xd1\x81\xd0\xba\xd0\xb2\xd0\xb0","url":"https://api.hh.ru/areas/1"},"salary":null,"type":{"id":"open","name":"\xd0\x9e\xd1\x82\xd0\xba\xd1\x80\xd1\x8b\xd1\x82\xd0\xb0\xd1\x8f"},"address":{"city":"\xd0\x9c\xd0\xbe\xd1\x81\xd0\xba\xd0\xb2\xd0\xb0","street":"\xd0\x9e\xd1\x82\xd1\x80\xd0\xb0\xd0\xb4\xd0\xbd\xd0\xb0\xd1\x8f \xd1\x83\xd0\xbb\xd0\xb8\xd1\x86\xd0\ ...

# %%
import requests
appid = 'e8e123e17fb34e6b9ec170847221804'
url = 'https://samples.openweathermap.org/data/2.5/weather' 
req = requests.get(f'{url}?q=Paris,uk&appid={appid}') 
print(req.json())
# Out:
# {'coord': {'lon': -0.13, 'lat': 51.51}, 'weather': [{'id': 300, 'main': 'Drizzle', 'description': 'light intensity drizzle', 'icon': '09d'}], 'base': 'stations', 'main': {'temp': 280.32, 'pressure': 1012, 'humidity': 81, 'temp_min': 279.15, 'temp_max': 281.15}, 'visibility': 10000, 'wind': {'speed': 4.1, 'deg': 80}, 'clouds': {'all': 90}, 'dt': 1485789600, 'sys': {'type': 1, 'id': 5091, 'message': 0.0103, 'country': 'GB', 'sunrise': 1485762037, 'sunset': 1485794875}, 'id': 2643743, 'name': 'London', 'cod': 200}
